# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Write your code here
url = 'D:/AI-Course/AI-DS-Exercises/AI-DS-Exercises/Chapter 1/8. Matplotlib/company_sales_data.csv'

data = pd.read_csv(url)
#print(data)
df = pd.DataFrame(data)

plt.plot(df['month_number'], df['total_profit'])
plt.xlabel('Month number')
plt.ylabel('Total profit')
plt.title('Company profit per month')
# Out:
# Text(0.5, 1.0, 'Company profit per month')

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
x = df['month_number']
y = df['total_units']

plt.plot(x, y, '--', color= 'red', linewidth = 3, marker= 'o', markerfacecolor = 'black',  label='total units')
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.title('Company sales data of last year')



plt.grid(False)

plt.legend()
plt.legend(loc='lower right')

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
detailed_data = data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
fig, ax = plt.subplots(figsize=(10,8))


plt.xlabel('month numbers')
plt.ylabel('Sales units in number')
plt.title('Sales Data')
plt.plot(df['month_number'], df['facecream'], marker= 'o',  label='faceceam Sales Data')
plt.plot(df['month_number'], df['facewash'], marker= 'o',  label='facewash Sales Data')
plt.plot(df['month_number'], df['toothpaste'], marker= 'o',  label='toothpaste Sales Data')
plt.plot(df['month_number'], df['bathingsoap'], marker= 'o',  label='bathingsoap Sales Data')
plt.plot(df['month_number'], df['shampoo'], marker= 'o',  label='shampoo Sales Data')
plt.plot(df['month_number'], df['moisturizer'], marker= 'o',  label='moisturizer Sales Data')
plt.legend()
plt.legend(loc='upper left')

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here


df.plot.scatter(x='month_number', y='toothpaste')
plt.xlabel('Month Number')
plt.ylabel('Number of units sold')
plt.title('Toothpaste Sales Data')
plt.grid(True, linestyle='--')

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('Facewash and Facecream Sales Data')

plt.grid(True, linestyle='--')

x_axis = df['month_number']
y_cream = df['facecream']
z_wash = df['facewash']

ax = plt.subplot(111)
ax.bar(x_axis-0.2, y_cream, width=0.4, align='center', label = "Facewash")
ax.bar(x_axis+0.2, z_wash, width=0.4, align='center', label = "Facecream")
plt.legend()

plt.show()
# Out:
# <ipython-input-151-31a616b6cfcb>:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
"""
x_axis = df['month_number']
y_bathingsoap = df['bathingsoap']

fig, axis = plt.subplots(2,sharex=True)
axis[0].plot(x_axis, y_bathingsoap, label="sales of bathing soap")
axis[1].plot(x_axis, y_bathingsoap)

plt.grid(True, linestyle='--')

ax.bar(x_axis, y_bathingsoap, width=0.4, align='center')

plt.legend()

plt.show()
"""
df.plot.bar(x='month_number', y='bathingsoap')
plt.xlabel('Month Number')
plt.ylabel('Number of units sold')
plt.title('Toothpaste Sales Data')
plt.grid(True, linestyle='--')

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

df['total_profit'].plot.hist(bins=6)

plt.xlabel('profit range in dollars')
plt.ylabel('Actual profit in dollar')
plt.title('Profit Data')
# Out:
# Text(0.5, 1.0, 'Profit Data')

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

pie_labels=data.drop(['month_number','total_units','total_profit'],axis = 1).sum(axis=0,skipna=True).keys().tolist()
pie_value=data.drop(['month_number','total_units','total_profit'],axis = 1).sum(axis=0,skipna=True).values.tolist()

fig, ax = plt.subplots(figsize=(10,10))
ax.pie(pie_value, labels=pie_labels)
ax.axis('equal')

ax.legend(loc='lower right', bbox_to_anchor=(1.2,0.0))

plt.show()

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig, (ax1, ax2) = plt.subplots(2,1,sharex=True,figsize=(12,8))

ax1.plot(data['month_number'],data['bathingsoap'], marker = 'o', c='k', linewidth =4)
ax1.set_title('Sales data of bath soap')

ax2.plot(data['month_number'],data['facewash'], marker = 'o', c='r', linewidth =4)
ax2.set_title('Sales data of facewash')

plt.ylabel('Sales units in number')

fig.show()
# Out:
# <ipython-input-182-7a2809ff772b>:12: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here



stack_data=data.drop(['total_units','total_profit','month_number'],axis=1)
labels = stack_data.columns.values

fig, ax = plt.subplots(figsize=(14,8))

ax.stackplot(data['month_number'].values, stack_data.T, labels=labels)
ax.legend(loc='upper left')

plt.show()
