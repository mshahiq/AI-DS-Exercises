# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
import numpy as np
import re

# %%
def web_extraction():
    movie_names = []
    release_date = []
    description = []
    directors = []
    movie_stars = []
    ratings = []
    duration = []
    genre = []

    #url = 'https://www.imdb.com/list/ls009668711/';
    url = 'https://www.imdb.com/list/ls009668711/?sort=moviemeter,asc&st_dt=&mode=detail&page=1'
    pth = 'chromedriver.exe'

    driver = webdriver.Chrome(pth)

    driver.get(url)
    
    sleep(20)

    movies = 100
    for i in range(1,movies+1):
        
        movie = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/h3/a')
                                    
        release = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/h3/span[2]')

                                                 
        desc = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/p[2]')
                                                
        dire = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/p[3]/a[1]')

        rat = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/div[1]/div[1]/span[2]')

        dura = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/p[1]/span[3]')

        gen = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/p[1]/span[5]')
                                            
        movie_ = movie.text
        movie_names.append(movie_)
        
        whole = driver.find_element_by_xpath(f'/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div[{i}]/div[2]/p[3]')
        whole_ = whole.text
        director, space, stars = whole_.partition('Stars: ')
        movie_stars.append(stars)
    
    
        release_ = release.text
        find_wo_brackets = release_.replace('(','')
        find_wo_brackets = find_wo_brackets.replace(')','')

        if i == 10:
            find_wo_brackets = 2004
        if i == 38:
            find_wo_brackets = 2015
        if i == 84:
            find_wo_brackets = 2006
        release_date.append(int(find_wo_brackets))

        description_ = desc.text
        description.append(description_)

        directors_ = dire.text
        directors.append(directors_)

        ratings_ = rat.text
        int_ratings_ = float(ratings_)
        ratings.append(int_ratings_)

        duration_ = dura.text
        durat, space, stri = duration_.partition(' ')
        int_duration = int(durat)
        duration.append(int_duration)

        genres_ = gen.text
        genre.append(genres_)

#########################################       SAVING IT INTO PANDAS DATAFRAME        #######################################################################
  
    data = {'Movies':movie_names,'Description':description,'Directors':directors,'Movie Stars':movie_stars,'Genre':genre,'Release Date':release_date,'Duration (in mins)':duration,'Ratings':ratings}
    
    
    
    labels = pd.RangeIndex(start=1,stop=movies+1,step=1)
    
    df = pd.DataFrame(data,index =labels).rename_axis('Serial Number',axis=1)
    df.to_csv('drama_imdb.csv')
    
    return df

web_extraction()
# Out:
# Serial Number                  Movies  \
# 1                       The Godfather
# 2              The Godfather: Part II
# 3                     The Dark Knight
# 4                        Pulp Fiction
# 5                                Heat
# ..                                ...
# 96                         La La Land
# 97                 A Clockwork Orange
# 98                 The Shape of Water
# 99                                JFK
# 100                         Prisoners
#
# Serial Number                                        Description  \
# 1              The aging patriarch of an organized crime dyna...
# 2              The early life and career of Vito Corleone in ...
# 3              When the menace known as the Joker wreaks havo...
# 4              The lives of two mob hitmen, a boxer, a gangst...
# 5              A group of high-end professional thieves start...
# ..                                                           ...
# 96             While navigating their careers in Los Angeles,...
# 97             In the future, a sadistic gang leader is impri...
# 98             At a top secret research facility in the 1960s...
# 99             New Orleans District Attorney Jim Garrison dis...
# 100            When Keller Dover's daughter and her friend go...
#
# Serial Number             Directors  \
# 1              Francis Ford Coppola
# 2              Francis Ford Coppola
# 3                 Christopher Nolan
# 4                 Quentin Tarantino
# 5                      Michael Mann
# ..                              ...
# 96                  Damien Chazelle
# 97                  Stanley Kubrick
# 98               Guillermo del Toro
# 99                     Oliver Stone
# 100                Denis Villeneuve
#
# Serial Number                                        Movie Stars  \
# 1              Marlon Brando, Al Pacino, James Caan, Diane Ke...
# 2              Al Pacino, Robert De Niro, Robert Duvall, Dian...
# 3              Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4              John Travolta, Uma Thurman, Samuel L. Jackson,...
# 5              Al Pacino, Robert De Niro, Val Kilmer, Jon Voight
# ..                                                           ...
# 96             Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# 97             Malcolm McDowell, Patrick Magee, Michael Bates...
# 98             Sally Hawkins, Octavia Spencer, Michael Shanno...
# 99             Kevin Costner, Gary Oldman, Jack Lemmon, Walte...
# 100            Hugh Jackman, Jake Gyllenhaal, Viola Davis, Me...
#
# Serial Number                     Genre  Release Date  Duration (in mins)  \
# 1                          Crime, Drama          1972                 175
# 2                          Crime, Drama          1974                 202
# 3                  Action, Crime, Drama          2008                 152
# 4                          Crime, Drama          1994                 154
# 5                  Action, Crime, Drama          1995                 170
# ..                                  ...           ...                 ...
# 96                 Comedy, Drama, Music          2016                 128
# 97                        Crime, Sci-Fi          1971                 136
# 98              Drama, Fantasy, Romance          2017                 123
# 99             Drama, History, Thriller          1991                 189
# 100               Crime, Drama, Mystery          2013                 153
#
# Serial Number  Ratings
# 1                  9.2
# 2                  9.0
# 3                  9.0
# 4                  8.9
# 5                  8.2
# ..                 ...
# 96                 8.0
# 97                 8.3
# 98                 7.3
# 99                 8.0
# 100                8.1
#
# [100 rows x 8 columns]

# %%
df_new = pd.read_csv('drama_imdb.csv',index_col=0)
df_new
# Out:
#                                          Movies  \
# Serial Number
# 1              Once Upon a Time... In Hollywood
# 2                      The Shawshank Redemption
# 3                               The Dark Knight
# 4                                 The Godfather
# 5                                    Fight Club
# ...                                         ...
# 96                       A Very Long Engagement
# 97                           Children of Heaven
# 98                           The Legend of 1900
# 99                                         1900
# 100                                   Stalag 17
#
#                                                      Description  \
# Serial Number
# 1              A faded television actor and his stunt double ...
# 2              Two imprisoned men bond over a number of years...
# 3              When the menace known as the Joker wreaks havo...
# 4              The aging patriarch of an organized crime dyna...
# 5              An insomniac office worker and a devil-may-car...
# ...                                                          ...
# 96             Tells the story of a young woman's relentless ...
# 97             After a boy loses his sister's pair of shoes, ...
# 98             A baby boy, discovered in 1900 on an ocean lin...
# 99             The epic tale of a class struggle in twentieth...
# 100            After two Americans are killed while escaping ...
#
#                           Directors  \
# Serial Number
# 1                 Quentin Tarantino
# 2                    Frank Darabont
# 3                 Christopher Nolan
# 4              Francis Ford Coppola
# 5                     David Fincher
# ...                             ...
# 96               Jean-Pierre Jeunet
# 97                     Majid Majidi
# 98               Giuseppe Tornatore
# 99              Bernardo Bertolucci
# 100                    Billy Wilder
#
#                                                      Movie Stars  \
# Serial Number
# 1              Leonardo DiCaprio, Brad Pitt, Margot Robbie, E...
# 2              Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 3              Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4              Marlon Brando, Al Pacino, James Caan, Diane Ke...
# 5              Brad Pitt, Edward Norton, Meat Loaf, Zach Grenier
# ...                                                          ...
# 96             Audrey Tautou, Gaspard Ulliel, Jodie Foster, D...
# 97             Mohammad Amir Naji, Amir Farrokh Hashemian, Ba...
# 98             Tim Roth, Pruitt Taylor Vince, Mélanie Thierry...
# 99             Robert De Niro, Gérard Depardieu, Dominique Sa...
# 100            William Holden, Don Taylor, Otto Preminger, Ro...
#
#                                  Genre  Release Date  Duration (in mins)  \
# Serial Number
# 1                        Comedy, Drama          2019                 161
# 2                                Drama          1994                 142
# 3                 Action, Crime, Drama          2008                 152
# 4                         Crime, Drama          1972                 175
# 5                                Drama          1999                 139
# ...                                ...           ...                 ...
# 96             Drama, Mystery, Romance          2004                 133
# 97                Drama, Family, Sport          1997                  89
# 98               Drama, Music, Romance          1998                 169
# 99                      Drama, History          1976                 317
# 100                 Comedy, Drama, War          1953                 116
#
#                Ratings
# Serial Number
# 1                  7.6
# 2                  9.3
# 3                  9.0
# 4                  9.2
# 5                  8.8
# ...                ...
# 96                 7.6
# 97                 8.3
# 98                 8.1
# 99                 7.7
# 100                8.0
#
# [100 rows x 8 columns]

# %%
df_new.sort_values(by='Release Date',ascending=True)
# Out:
#                                                   Movies  \
# Serial Number
# 68                                    Gone with the Wind
# 78                                          Citizen Kane
# 59                                            Casablanca
# 100                                            Stalag 17
# 92                                     On the Waterfront
# ...                                                  ...
# 55                                            La La Land
# 38                                    The Shape of Water
# 63             Three Billboards Outside Ebbing, Missouri
# 47                                            Green Book
# 1                       Once Upon a Time... In Hollywood
#
#                                                      Description  \
# Serial Number
# 68             The manipulative daughter of a Georgia plantat...
# 78             Following the death of publishing tycoon Charl...
# 59             A cynical expatriate American cafe owner strug...
# 100            After two Americans are killed while escaping ...
# 92             An ex-prize fighter turned New Jersey longshor...
# ...                                                          ...
# 55             While navigating their careers in Los Angeles,...
# 38             At a top secret research facility in the 1960s...
# 63             A mother personally challenges the local autho...
# 47             A working-class Italian-American bouncer becom...
# 1              A faded television actor and his stunt double ...
#
#                         Directors  \
# Serial Number
# 68                 Victor Fleming
# 78                   Orson Welles
# 59                 Michael Curtiz
# 100                  Billy Wilder
# 92                     Elia Kazan
# ...                           ...
# 55                Damien Chazelle
# 38             Guillermo del Toro
# 63                Martin McDonagh
# 47                 Peter Farrelly
# 1               Quentin Tarantino
#
#                                                      Movie Stars  \
# Serial Number
# 68             Clark Gable, Vivien Leigh, Thomas Mitchell, Ba...
# 78             Orson Welles, Joseph Cotten, Dorothy Comingore...
# 59             Humphrey Bogart, Ingrid Bergman, Paul Henreid,...
# 100            William Holden, Don Taylor, Otto Preminger, Ro...
# 92             Marlon Brando, Karl Malden, Lee J. Cobb, Rod S...
# ...                                                          ...
# 55             Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# 38             Sally Hawkins, Octavia Spencer, Michael Shanno...
# 63             Frances McDormand, Woody Harrelson, Sam Rockwe...
# 47             Viggo Mortensen, Mahershala Ali, Linda Cardell...
# 1              Leonardo DiCaprio, Brad Pitt, Margot Robbie, E...
#
#                                   Genre  Release Date  Duration (in mins)  \
# Serial Number
# 68              Drama, History, Romance          1939                 238
# 78                       Drama, Mystery          1941                 119
# 59                  Drama, Romance, War          1942                 102
# 100                  Comedy, Drama, War          1953                 116
# 92               Crime, Drama, Thriller          1954                 108
# ...                                 ...           ...                 ...
# 55                 Comedy, Drama, Music          2016                 128
# 38              Drama, Fantasy, Romance          2017                 123
# 63                 Comedy, Crime, Drama          2017                 115
# 47             Biography, Comedy, Drama          2018                 130
# 1                         Comedy, Drama          2019                 161
#
#                Ratings
# Serial Number
# 68                 8.1
# 78                 8.3
# 59                 8.5
# 100                8.0
# 92                 8.1
# ...                ...
# 55                 8.0
# 38                 7.3
# 63                 8.1
# 47                 8.2
# 1                  7.6
#
# [100 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
