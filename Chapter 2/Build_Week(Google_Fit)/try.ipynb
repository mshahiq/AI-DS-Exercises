# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn import datasets
from sklearn import model_selection
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.pipeline import make_pipeline

# %%
url = 'D:\AI-Course\AI-Engineering\AI-Engineering\Chapter 2\Build Week\dataset_halfSecondWindow.csv'
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (62585, 71)

# %%
# Sensors of First Class of Classification (Sensor 1: Accelerometer)
x = df['android.sensor.accelerometer#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of accelerometer and target')
plt.xlabel('accelerometer')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of First Class of Classification (Sensor 2: Sound)
x = df['sound#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Sound and target')
plt.xlabel('sound')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of First Class of Classification (Sensor 3: Gyroscope)
x = df['android.sensor.gyroscope#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Gyroscope and target')
plt.xlabel('gyroscope')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of Second Class of Classification (Sensor 3: Orientation)
x = df['android.sensor.orientation#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Orientation and target')
plt.xlabel('orientation')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of Second Class of Classification (Sensor 4: Linear Acceleration)
x = df['android.sensor.linear_acceleration#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Linear Acceleration and target')
plt.xlabel('Linear Acceleration')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of Second Class of Classification (Sensor 6: Rotation Vector)
x = df['android.sensor.rotation_vector#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Rotation Vector and target')
plt.xlabel('Rotation Vector')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of Second Class of Classification (Sensor 7: Game Rotation Vector)
x = df['android.sensor.game_rotation_vector#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Game Rotation Vector and target')
plt.xlabel('Game Rotation Vector')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of Second Class of Classification (Sensor 8: gyroscope_uncalibrated)
x = df['android.sensor.gyroscope_uncalibrated#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Gyroscope (Uncalibrated) and target')
plt.xlabel('Gyroscope Uncalibrated')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')

# %%
# Sensors of Third Class of Classification (Sensor 5: Speed)
x = df['speed#mean']
y = df['target']

plt.scatter(x,y)
plt.title('Scatter diagram of Speed and target')
plt.xlabel('Speed')
plt.ylabel('target')
# Out:
# Text(0, 0.5, 'target')
