# %% [markdown]
# ### Loading the dataset

# %%
car_data = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data"
car_names = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.names"

# %%
import pandas as pd
df = pd.read_csv(car_data)
df
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
attributes = ['buying','maint','doors','persons','lug_boot','safety','target']
df = pd.read_csv(car_data,header=None,index_col=False,names=attributes)
df
# Out:
#      buying  maint  doors persons lug_boot safety target
# 0     vhigh  vhigh      2       2    small    low  unacc
# 1     vhigh  vhigh      2       2    small    med  unacc
# 2     vhigh  vhigh      2       2    small   high  unacc
# 3     vhigh  vhigh      2       2      med    low  unacc
# 4     vhigh  vhigh      2       2      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %% [markdown]
# ### Preparing the dataset

# %%
df = df.replace(['vhigh','high','med','low','small','big'],[4,3,2,1,1,3])
df
# Out:
#       buying  maint  doors persons  lug_boot  safety target
# 0          4      4      2       2         1       1  unacc
# 1          4      4      2       2         1       2  unacc
# 2          4      4      2       2         1       3  unacc
# 3          4      4      2       2         2       1  unacc
# 4          4      4      2       2         2       2  unacc
# ...      ...    ...    ...     ...       ...     ...    ...
# 1723       1      1  5more    more         2       2   good
# 1724       1      1  5more    more         2       3  vgood
# 1725       1      1  5more    more         3       1  unacc
# 1726       1      1  5more    more         3       2   good
# 1727       1      1  5more    more         3       3  vgood
#
# [1728 rows x 7 columns]

# %%
df.doors = df.doors.replace('5more',5)

# %%
df.persons = df.persons.replace('more',5)

# %%
df
# Out:
#       buying  maint doors persons  lug_boot  safety target
# 0          4      4     2       2         1       1  unacc
# 1          4      4     2       2         1       2  unacc
# 2          4      4     2       2         1       3  unacc
# 3          4      4     2       2         2       1  unacc
# 4          4      4     2       2         2       2  unacc
# ...      ...    ...   ...     ...       ...     ...    ...
# 1723       1      1     5       5         2       2   good
# 1724       1      1     5       5         2       3  vgood
# 1725       1      1     5       5         3       1  unacc
# 1726       1      1     5       5         3       2   good
# 1727       1      1     5       5         3       3  vgood
#
# [1728 rows x 7 columns]

# %% [markdown]
# ### Train Test Split

# %%
X,y = df.iloc[:,:-1],df.target

# %%
from sklearn.model_selection import train_test_split,cross_validate
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtree_clf = DecisionTreeClassifier(random_state=42)
dt_clf = dtree_clf.fit(X_train,y_train)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(50,50))
plot_tree(dt_clf,
          filled =True,
          rounded=True,
          class_names=["unacc","acc","good","vgood"],
          feature_names=X.columns)
# Out:
# [Text(1662.9420731707316, 2613.4615384615386, 'safety <= 1.5\ngini = 0.452\nsamples = 1209\nvalue = [266, 50, 852, 41]\nclass = good'),
#  Text(1628.9176829268292, 2404.3846153846152, 'gini = 0.0\nsamples = 407\nvalue = [0, 0, 407, 0]\nclass = good'),
#  Text(1696.966463414634, 2404.3846153846152, 'persons <= 3.0\ngini = 0.576\nsamples = 802\nvalue = [266, 50, 445, 41]\nclass = good'),
#  Text(1662.9420731707316, 2195.3076923076924, 'gini = 0.0\nsamples = 260\nvalue = [0, 0, 260, 0]\nclass = good'),
#  Text(1730.9908536585365, 2195.3076923076924, 'buying <= 2.5\ngini = 0.628\nsamples = 542\nvalue = [266, 50, 185, 41]\nclass = unacc'),
#  Text(893.140243902439, 1986.2307692307693, 'maint <= 1.5\ngini = 0.646\nsamples = 264\nvalue = [139, 50, 34, 41]\nclass = unacc'),
#  Text(314.7256097560975, 1777.1538461538462, 'safety <= 2.5\ngini = 0.612\nsamples = 65\nvalue = [9, 35, 3, 18]\nclass = acc'),
#  Text(170.1219512195122, 1568.076923076923, 'lug_boot <= 1.5\ngini = 0.456\nsamples = 31\nvalue = [9, 21, 1, 0]\nclass = acc'),
#  Text(102.07317073170731, 1359.0, 'doors <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 1, 0]\nclass = unacc'),
#  Text(68.04878048780488, 1149.923076923077, 'buying <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = unacc'),
#  Text(34.02439024390244, 940.846153846154, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(102.07317073170731, 940.846153846154, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(136.09756097560975, 1149.923076923077, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = unacc'),
#  Text(238.17073170731706, 1359.0, 'doors <= 2.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21, 0, 0]\nclass = acc'),
#  Text(204.14634146341461, 1149.923076923077, 'lug_boot <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4, 0, 0]\nclass = acc'),
#  Text(170.1219512195122, 940.846153846154, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(238.17073170731706, 940.846153846154, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = acc'),
#  Text(272.1951219512195, 1149.923076923077, 'gini = 0.0\nsamples = 17\nvalue = [0, 17, 0, 0]\nclass = acc'),
#  Text(459.3292682926829, 1568.076923076923, 'lug_boot <= 1.5\ngini = 0.547\nsamples = 34\nvalue = [0, 14, 2, 18]\nclass = vgood'),
#  Text(374.2682926829268, 1359.0, 'doors <= 2.5\ngini = 0.298\nsamples = 11\nvalue = [0, 9, 2, 0]\nclass = acc'),
#  Text(340.2439024390244, 1149.923076923077, 'persons <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]\nclass = acc'),
#  Text(306.2195121951219, 940.846153846154, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = acc'),
#  Text(374.2682926829268, 940.846153846154, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = good'),
#  Text(408.29268292682923, 1149.923076923077, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = acc'),
#  Text(544.390243902439, 1359.0, 'doors <= 2.5\ngini = 0.34\nsamples = 23\nvalue = [0, 5, 0, 18]\nclass = vgood'),
#  Text(476.3414634146341, 1149.923076923077, 'lug_boot <= 2.5\ngini = 0.49\nsamples = 7\nvalue = [0, 4, 0, 3]\nclass = acc'),
#  Text(442.3170731707317, 940.846153846154, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = acc'),
#  Text(510.3658536585366, 940.846153846154, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = vgood'),
#  Text(612.4390243902438, 1149.923076923077, 'doors <= 3.5\ngini = 0.117\nsamples = 16\nvalue = [0, 1, 0, 15]\nclass = vgood'),
#  Text(578.4146341463414, 940.846153846154, 'persons <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 4]\nclass = vgood'),
#  Text(544.390243902439, 731.769230769231, 'lug_boot <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = acc'),
#  Text(510.3658536585366, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(578.4146341463414, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = vgood'),
#  Text(612.4390243902438, 731.769230769231, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = vgood'),
#  Text(646.4634146341464, 940.846153846154, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11]\nclass = vgood'),
#  Text(1471.5548780487804, 1777.1538461538462, 'maint <= 2.5\ngini = 0.53\nsamples = 199\nvalue = [130, 15, 31, 23]\nclass = unacc'),
#  Text(1105.7926829268292, 1568.076923076923, 'safety <= 2.5\ngini = 0.65\nsamples = 64\nvalue = [32, 15, 4, 13]\nclass = unacc'),
#  Text(901.6463414634146, 1359.0, 'buying <= 1.5\ngini = 0.402\nsamples = 39\nvalue = [29, 8, 2, 0]\nclass = unacc'),
#  Text(782.560975609756, 1149.923076923077, 'lug_boot <= 1.5\ngini = 0.554\nsamples = 17\nvalue = [8, 8, 1, 0]\nclass = unacc'),
#  Text(714.5121951219512, 940.846153846154, 'doors <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 0, 1, 0]\nclass = unacc'),
#  Text(680.4878048780488, 731.769230769231, 'persons <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = unacc'),
#  Text(646.4634146341464, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(714.5121951219512, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(748.5365853658536, 731.769230769231, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = unacc'),
#  Text(850.609756097561, 940.846153846154, 'doors <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8, 0, 0]\nclass = acc'),
#  Text(816.5853658536585, 731.769230769231, 'lug_boot <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0, 0]\nclass = acc'),
#  Text(782.560975609756, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(850.609756097561, 522.6923076923076, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = acc'),
#  Text(884.6341463414634, 731.769230769231, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = acc'),
#  Text(1020.7317073170732, 1149.923076923077, 'doors <= 2.5\ngini = 0.087\nsamples = 22\nvalue = [21, 0, 1, 0]\nclass = unacc'),
#  Text(986.7073170731707, 940.846153846154, 'lug_boot <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 1, 0]\nclass = unacc'),
#  Text(952.6829268292682, 731.769230769231, 'persons <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = unacc'),
#  Text(918.6585365853658, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(986.7073170731707, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(1020.7317073170732, 731.769230769231, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = unacc'),
#  Text(1054.7560975609756, 940.846153846154, 'gini = 0.0\nsamples = 16\nvalue = [16, 0, 0, 0]\nclass = unacc'),
#  Text(1309.939024390244, 1359.0, 'lug_boot <= 1.5\ngini = 0.63\nsamples = 25\nvalue = [3, 7, 2, 13]\nclass = vgood'),
#  Text(1190.8536585365853, 1149.923076923077, 'buying <= 1.5\ngini = 0.595\nsamples = 11\nvalue = [3, 6, 2, 0]\nclass = acc'),
#  Text(1122.8048780487804, 940.846153846154, 'doors <= 2.5\ngini = 0.245\nsamples = 7\nvalue = [0, 6, 1, 0]\nclass = acc'),
#  Text(1088.780487804878, 731.769230769231, 'persons <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = acc'),
#  Text(1054.7560975609756, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(1122.8048780487804, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(1156.8292682926829, 731.769230769231, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = acc'),
#  Text(1258.90243902439, 940.846153846154, 'doors <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1, 0]\nclass = unacc'),
#  Text(1224.8780487804877, 731.769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(1292.9268292682927, 731.769230769231, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = unacc'),
#  Text(1429.0243902439024, 1149.923076923077, 'doors <= 2.5\ngini = 0.133\nsamples = 14\nvalue = [0, 1, 0, 13]\nclass = vgood'),
#  Text(1395.0, 940.846153846154, 'lug_boot <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2]\nclass = vgood'),
#  Text(1360.9756097560976, 731.769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(1429.0243902439024, 731.769230769231, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = vgood'),
#  Text(1463.0487804878048, 940.846153846154, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11]\nclass = vgood'),
#  Text(1837.3170731707316, 1568.076923076923, 'lug_boot <= 1.5\ngini = 0.428\nsamples = 135\nvalue = [98, 0, 27, 10]\nclass = unacc'),
#  Text(1633.170731707317, 1359.0, 'safety <= 2.5\ngini = 0.492\nsamples = 48\nvalue = [27, 0, 21, 0]\nclass = unacc'),
#  Text(1565.121951219512, 1149.923076923077, 'maint <= 3.5\ngini = 0.298\nsamples = 22\nvalue = [4, 0, 18, 0]\nclass = good'),
#  Text(1531.0975609756097, 940.846153846154, 'buying <= 1.5\ngini = 0.48\nsamples = 10\nvalue = [4, 0, 6, 0]\nclass = good'),
#  Text(1497.0731707317073, 731.769230769231, 'doors <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 1, 0]\nclass = unacc'),
#  Text(1463.0487804878048, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(1531.0975609756097, 522.6923076923076, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = unacc'),
#  Text(1565.121951219512, 731.769230769231, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = good'),
#  Text(1599.1463414634145, 940.846153846154, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0]\nclass = good'),
#  Text(1701.219512195122, 1149.923076923077, 'doors <= 2.5\ngini = 0.204\nsamples = 26\nvalue = [23, 0, 3, 0]\nclass = unacc'),
#  Text(1667.1951219512196, 940.846153846154, 'persons <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 3, 0]\nclass = unacc'),
#  Text(1633.170731707317, 731.769230769231, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = unacc'),
#  Text(1701.219512195122, 731.769230769231, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = good'),
#  Text(1735.2439024390244, 940.846153846154, 'gini = 0.0\nsamples = 20\nvalue = [20, 0, 0, 0]\nclass = unacc'),
#  Text(2041.4634146341464, 1359.0, 'buying <= 1.5\ngini = 0.316\nsamples = 87\nvalue = [71, 0, 6, 10]\nclass = unacc'),
#  Text(1905.3658536585365, 1149.923076923077, 'maint <= 3.5\ngini = 0.392\nsamples = 43\nvalue = [32, 0, 1, 10]\nclass = unacc'),
#  Text(1803.2926829268292, 940.846153846154, 'safety <= 2.5\ngini = 0.496\nsamples = 22\nvalue = [12, 0, 0, 10]\nclass = unacc'),
#  Text(1769.2682926829268, 731.769230769231, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0]\nclass = unacc'),
#  Text(1837.3170731707316, 731.769230769231, 'lug_boot <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [3, 0, 0, 10]\nclass = vgood'),
#  Text(1803.2926829268292, 522.6923076923076, 'doors <= 4.0\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 0, 2]\nclass = unacc'),
#  Text(1769.2682926829268, 313.61538461538476, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = unacc'),
#  Text(1837.3170731707316, 313.61538461538476, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = vgood'),
#  Text(1871.341463414634, 522.6923076923076, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]\nclass = vgood'),
#  Text(2007.439024390244, 940.846153846154, 'doors <= 2.5\ngini = 0.091\nsamples = 21\nvalue = [20, 0, 1, 0]\nclass = unacc'),
#  Text(1973.4146341463413, 731.769230769231, 'safety <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 1, 0]\nclass = unacc'),
#  Text(1939.390243902439, 522.6923076923076, 'lug_boot <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = unacc'),
#  Text(1905.3658536585365, 313.61538461538476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(1973.4146341463413, 313.61538461538476, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(2007.439024390244, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(2041.4634146341464, 731.769230769231, 'gini = 0.0\nsamples = 16\nvalue = [16, 0, 0, 0]\nclass = unacc'),
#  Text(2177.560975609756, 1149.923076923077, 'doors <= 3.5\ngini = 0.201\nsamples = 44\nvalue = [39, 0, 5, 0]\nclass = unacc'),
#  Text(2143.5365853658536, 940.846153846154, 'safety <= 2.5\ngini = 0.363\nsamples = 21\nvalue = [16, 0, 5, 0]\nclass = unacc'),
#  Text(2109.512195121951, 731.769230769231, 'lug_boot <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [6, 0, 5, 0]\nclass = unacc'),
#  Text(2075.487804878049, 522.6923076923076, 'doors <= 2.5\ngini = 0.408\nsamples = 7\nvalue = [2, 0, 5, 0]\nclass = good'),
#  Text(2041.4634146341464, 313.61538461538476, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = good'),
#  Text(2109.512195121951, 313.61538461538476, 'persons <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2, 0]\nclass = unacc'),
#  Text(2075.487804878049, 104.53846153846189, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = good'),
#  Text(2143.5365853658536, 104.53846153846189, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(2143.5365853658536, 522.6923076923076, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = unacc'),
#  Text(2177.560975609756, 731.769230769231, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]\nclass = unacc'),
#  Text(2211.5853658536585, 940.846153846154, 'gini = 0.0\nsamples = 23\nvalue = [23, 0, 0, 0]\nclass = unacc'),
#  Text(2568.8414634146343, 1986.2307692307693, 'maint <= 2.5\ngini = 0.496\nsamples = 278\nvalue = [127, 0, 151, 0]\nclass = good'),
#  Text(2415.731707317073, 1777.1538461538462, 'safety <= 2.5\ngini = 0.382\nsamples = 144\nvalue = [107, 0, 37, 0]\nclass = unacc'),
#  Text(2313.6585365853657, 1568.076923076923, 'lug_boot <= 1.5\ngini = 0.5\nsamples = 71\nvalue = [36, 0, 35, 0]\nclass = unacc'),
#  Text(2279.6341463414633, 1359.0, 'gini = 0.0\nsamples = 25\nvalue = [0, 0, 25, 0]\nclass = good'),
#  Text(2347.682926829268, 1359.0, 'doors <= 3.5\ngini = 0.34\nsamples = 46\nvalue = [36, 0, 10, 0]\nclass = unacc'),
#  Text(2313.6585365853657, 1149.923076923077, 'lug_boot <= 2.5\ngini = 0.491\nsamples = 23\nvalue = [13, 0, 10, 0]\nclass = unacc'),
#  Text(2279.6341463414633, 940.846153846154, 'persons <= 4.5\ngini = 0.355\nsamples = 13\nvalue = [3, 0, 10, 0]\nclass = good'),
#  Text(2245.609756097561, 731.769230769231, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0]\nclass = good'),
#  Text(2313.6585365853657, 731.769230769231, 'doors <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2, 0]\nclass = unacc'),
#  Text(2279.6341463414633, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = good'),
#  Text(2347.682926829268, 522.6923076923076, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = unacc'),
#  Text(2347.682926829268, 940.846153846154, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]\nclass = unacc'),
#  Text(2381.7073170731705, 1149.923076923077, 'gini = 0.0\nsamples = 23\nvalue = [23, 0, 0, 0]\nclass = unacc'),
#  Text(2517.80487804878, 1568.076923076923, 'doors <= 2.5\ngini = 0.053\nsamples = 73\nvalue = [71, 0, 2, 0]\nclass = unacc'),
#  Text(2483.780487804878, 1359.0, 'lug_boot <= 1.5\ngini = 0.198\nsamples = 18\nvalue = [16, 0, 2, 0]\nclass = unacc'),
#  Text(2449.7560975609754, 1149.923076923077, 'persons <= 4.5\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 2, 0]\nclass = unacc'),
#  Text(2415.731707317073, 940.846153846154, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = unacc'),
#  Text(2483.780487804878, 940.846153846154, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = good'),
#  Text(2517.80487804878, 1149.923076923077, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = unacc'),
#  Text(2551.829268292683, 1359.0, 'gini = 0.0\nsamples = 55\nvalue = [55, 0, 0, 0]\nclass = unacc'),
#  Text(2721.951219512195, 1777.1538461538462, 'buying <= 3.5\ngini = 0.254\nsamples = 134\nvalue = [20, 0, 114, 0]\nclass = good'),
#  Text(2687.9268292682927, 1568.076923076923, 'maint <= 3.5\ngini = 0.433\nsamples = 63\nvalue = [20, 0, 43, 0]\nclass = good'),
#  Text(2653.9024390243903, 1359.0, 'safety <= 2.5\ngini = 0.444\nsamples = 30\nvalue = [20, 0, 10, 0]\nclass = unacc'),
#  Text(2585.8536585365855, 1149.923076923077, 'lug_boot <= 2.5\ngini = 0.48\nsamples = 15\nvalue = [6, 0, 9, 0]\nclass = good'),
#  Text(2551.829268292683, 940.846153846154, 'doors <= 3.5\ngini = 0.298\nsamples = 11\nvalue = [2, 0, 9, 0]\nclass = good'),
#  Text(2517.80487804878, 731.769230769231, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = good'),
#  Text(2585.8536585365855, 731.769230769231, 'lug_boot <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2, 0]\nclass = unacc'),
#  Text(2551.829268292683, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = good'),
#  Text(2619.878048780488, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(2619.878048780488, 940.846153846154, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = unacc'),
#  Text(2721.951219512195, 1149.923076923077, 'doors <= 2.5\ngini = 0.124\nsamples = 15\nvalue = [14, 0, 1, 0]\nclass = unacc'),
#  Text(2687.9268292682927, 940.846153846154, 'lug_boot <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = unacc'),
#  Text(2653.9024390243903, 731.769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(2721.951219512195, 731.769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(2755.9756097560976, 940.846153846154, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = unacc'),
#  Text(2721.951219512195, 1359.0, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33, 0]\nclass = good'),
#  Text(2755.9756097560976, 1568.076923076923, 'gini = 0.0\nsamples = 71\nvalue = [0, 0, 71, 0]\nclass = good')]

# %% [markdown]
# ### Training Accuracy

# %%
cv = cross_validate(dt_clf,X_train,y_train,cv=5)

def print_scores(cv):
    #print out cross validation scores
    [print('Crossvalidation fold: {}  Accuracy: {}'.format(n, score)) for n, score in enumerate(cv['test_score'])]
    
    #print out the mean of the cross validation
    print('Mean train cross validation score {}'.format(cv['test_score'].mean()))
    
print_scores(cv)
# Out:
# Crossvalidation fold: 0  Accuracy: 0.9710743801652892
# Crossvalidation fold: 1  Accuracy: 0.9628099173553719
# Crossvalidation fold: 2  Accuracy: 0.9752066115702479
# Crossvalidation fold: 3  Accuracy: 0.9752066115702479
# Crossvalidation fold: 4  Accuracy: 0.9626556016597511
# Mean train cross validation score 0.9693906244641817

# %% [markdown]
# ### Test Accuracy

# %%
cv_test = cross_validate(dt_clf,X_test,y_test,cv=5)

def print_scores(cv):
    #print out cross validation scores
    [print('Crossvalidation fold: {}  Accuracy: {}'.format(n, score)) for n, score in enumerate(cv['test_score'])]
    
    #print out the mean of the cross validation
    print('Mean test cross validation score {}'.format(cv['test_score'].mean()))
    
print_scores(cv_test)
# Out:
# Crossvalidation fold: 0  Accuracy: 0.9134615384615384
# Crossvalidation fold: 1  Accuracy: 0.9423076923076923
# Crossvalidation fold: 2  Accuracy: 0.9519230769230769
# Crossvalidation fold: 3  Accuracy: 0.9423076923076923
# Crossvalidation fold: 4  Accuracy: 0.9029126213592233
# Mean test cross validation score 0.9305825242718446

# %% [markdown]
# ### Confusion matrix (of train values)

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(dt_clf, X_train, y_train, display_labels=["unacc","acc","good","vgood"],xticks_rotation=90)
# Out:
# C:\Users\shahi\anaconda3\envs\strive\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Confusion Matrix (of test values)

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(dt_clf, X_test, y_test, display_labels=["unacc","acc","good","vgood"],xticks_rotation=90)
# Out:
# C:\Users\shahi\anaconda3\envs\strive\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Accuracy Score

# %%
from sklearn.metrics import accuracy_score

predictions = dt_clf.predict(X_test)

acc_score = accuracy_score(y_test, predictions)
print("Accuracy score of test values:",round(acc_score,4)*100,"%")
# Out:
# Accuracy score of test values: 96.72 %
